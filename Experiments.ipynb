# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
import scipy.io
import pandas as pd
from numpy import genfromtxt
from sklearn.model_selection import *
from sklearn.svm import SVC
from sklearn.metrics import *
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.manifold import TSNE
import torch
from torch.autograd import Variable
from torch import nn
from torch.nn import *
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
import cv2
from torchmeta.modules import *
from collections import OrderedDict
from torch.utils.data import TensorDataset, DataLoader
from torchmeta.utils.data import *
import random
import maml
from maml.metalearners import ModelAgnosticMetaLearning
from torchmeta.utils.data import MetaDataset
import math

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## README.txt
#
# This folder contains the preliminary dataset for the coursework for R250: Applications of ML to Psychiatry.
#
# COBRE_demographics.csv includes a list of subject ids, labels, sex and age information.
# Labels: -1 for a healthy control subject, 1 for a patient with schizophrenia
# Sex: -1 for male, 1 for female
# PANSS total: these are symptom scores (from the Positive and Negative Syndrome Scale). Note controls do not have symptom data. Symptoms are also missing for 2 patients.
#
# COBRE_cortical_thickness.csv includes cortical thickness measurements for all subjects, for 308 cortical brain regions.
#
# COBRE_fmri_connectivity.mat is a Matlab file with connectivity data for all subjects. Subjects are listed in the same order as the demographics file above.
# Note that not only 293 out of 308 brain regions have fmri data available (due to incomplete fMRI coverage of the brain- some regions have signal drop out). These 293 regions are listed in the file COBRE_fmri_regions.csv.
# Also note that the values from the connectivity matrices are provided in vector format. To transform back to a connectivity matrix, you need to reshape the vectors.
# E.g. in Matlab, use the command: matrix = reshape(connectivity_data(ind,:),[293,293])
# where ind is an integer between 1 and 148 denoting the subject you are interested in. To check you have reshaped the matrix correctly, try plotting it- it should be a symmetric matrix with 1s on the diagonal.
#
# COBRE_fmri_connectivity.csv- as above but saved as a .csv file.
#
# COBRE_fmri_regions.csv- list of regions with fMRI data available (see above).

# %%
demographics = pd.read_csv("./data/COBRE_demographics.csv", sep=r'\s*,\s*', engine="python")
fmri_connectivity = pd.read_csv("./data/COBRE_fmri_connectivity.csv", sep=r'\s*,\s*', engine="python")
cortical_thickness = pd.read_csv("./data/COBRE_cortical_thickness.csv", sep=r'\s*,\s*', engine="python")
fmri_regions = pd.read_csv("./data/COBRE_fmri_regions.csv", sep=r'\s*,\s*', engine="python")
fmri_connectivity_np = genfromtxt("./data/COBRE_fmri_connectivity.csv", delimiter=',')

# %%
available_regions = np.concatenate((np.array([0]), fmri_regions['Region_no'].to_numpy() + 1))

# %% [markdown]
# # Quick data investigation

# %%
ages = demographics["age"]

c_pos_m = [0, 0, 0, 0]
c_con_m = [0, 0, 0, 0]

c_pos_f = [0, 0, 0, 0]
c_con_f = [0, 0, 0, 0]

for i in range(len(demographics["age"])):
    
    t_pos_m = 0
    t_neg_m = 0
    
    t_pos_f = 0
    t_neg_f = 0
    
    if(demographics["labels"][i] == -1):
        if(demographics["sex"][i] == -1):
            t_pos_m = 1
        else:
            t_pos_f = 1
    else:
        if(demographics["sex"][i] == -1):
            t_neg_m = 1
        else:
            t_neg_f = 1
            
    for j in range(4):
        min_age = (j+2)*10
        max_age = min_age + 10
        if(demographics["age"][i] > min_age and demographics["age"][i] < max_age):
            c_pos_m[j] += t_pos_m
            c_con_m[j] += t_neg_m
            c_pos_f[j] += t_pos_f
            c_con_f[j] += t_neg_f
         
            
print(c_pos_m)
print(c_con_m)

print(c_pos_f)
print(c_con_f)
# Out:
# [17, 13, 14, 10]
# [20, 6, 6, 12]
# [6, 6, 6, 3]
# [1, 4, 1, 2]

# %%
subject_to_data = {} # Each item to a tuple (Age, True / False, fMRI_connectivity_matrix, cortical_thickness)
for p in range(len(demographics["SubjectID"])):
    patient = demographics.iloc[p]
    p_fmri = fmri_connectivity_np[p, :]
    if(patient["sex"] != -1):
        continue 
    subject_to_data[patient["SubjectID"]] = [patient["age"], (patient["labels"] == -1), np.reshape(p_fmri, (293, 293)), np.zeros(308)]
    
for p in range(len(cortical_thickness["Subject_ID"])):
    patient = cortical_thickness.iloc[p]
    if(patient["Subject_ID"] not in subject_to_data):
        continue
    
    subject_to_data[patient["Subject_ID"]][3] = patient.to_numpy()[2:]

# %%
X = []
y = []
for pid, l in subject_to_data.items():
    x_temp = cv2.resize(l[2]*255, dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
    X.append(x_temp)
    y.append(int(l[1]))

X = np.array(X).astype(np.double)
y = np.array(y).astype(np.double)
    
train_x, val_x, train_y, val_y = train_test_split(X, y, test_size = 0.1)
print(train_x.shape, train_y.shape)
print(val_x.shape, val_y.shape)

train_x = train_x.reshape(102,1, 256, 256)
train_x  = torch.from_numpy(train_x)
val_x = val_x.reshape(12, 1, 256, 256)
val_x  = torch.from_numpy(val_x)

val_y = val_y.astype(int)
val_y = torch.from_numpy(val_y)
train_y = train_y.astype(int)
train_y = torch.from_numpy(train_y)
# Out:
# (102, 256, 256) (102,)
# (12, 256, 256) (12,)

# %%
d = {}
for pid, l in subject_to_data.items():
    x_temp = cv2.resize(l[2]*255, dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
    cat = (int(l[0] / 10)) - 2
    if cat not in [0, 1, 2, 3]:
        continue
    
    if cat not in d:
        d[cat] = []
    
    d[cat].append([int(l[1]), x_temp])
 
e = {}
for cat in d:
    l = np.array(d[cat])
    train_y = np.array(l[:, 0], dtype=np.int16)
    train_x = np.zeros(((math.ceil(.8* l[:, 1].shape[0])), l[:, 1][0].shape[0], l[:, 1][0].shape[1]))
    for i, item in enumerate(l[:, 1]):
        if(i >= train_x.shape[0]):
            break
        train_x[i, :, :] = item
    
    print(train_x.shape)
    train_x = np.expand_dims(train_x, axis=1)
    print(train_x.shape) 
    
    test_y = np.array(l[:math.ceil(.2*len(train_y)), 0], dtype=np.int16)
    
    test_x = np.zeros((math.ceil(.2* l[:, 1].shape[0]), l[:, 1][0].shape[0], l[:, 1][0].shape[1]))
    c = 0
    for i, item in reversed(list(enumerate(l[:, 1]))):
        if(c >= test_x.shape[0]):
            break
        test_x[c, :, :] = item
        c+=1

    test_x = np.expand_dims(test_x, axis=1)
    
    e[cat] = (train_x, train_y, test_x, test_y)
# Out:
# (17, 256, 256)
# (17, 1, 256, 256)
# (21, 256, 256)
# (21, 1, 256, 256)
# (32, 256, 256)
# (32, 1, 256, 256)
# (17, 256, 256)
# (17, 1, 256, 256)
# <ipython-input-12-50b7045c17cf>:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   l = np.array(d[cat])

# %% [markdown]
# ## Classification

# %%
# Without doing k-means classification

def get_results(subject_to_data, min_age, max_age):
    X = []
    y = []
    kf = KFold(n_splits=10, shuffle=False)
    for pid, l in subject_to_data.items():
        if(l[0] >= min_age and l[0] < max_age):
            X.append(l[2].flatten())
            #X.append(l[3])
            y.append(int(l[1]))
    
    X = np.array(X)
    y = np.array(y)
    kf.get_n_splits(X)
    
    acc = []
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        svclassifier = SVC(kernel='linear')
        svclassifier.fit(X_train, y_train)
        y_pred = svclassifier.predict(X_test)
        acc.append(accuracy_score(y_test, y_pred))
    
    acc = np.array(acc)
    return (np.mean(acc), np.std(acc))
    #print(confusion_matrix(y_test,y_pred))
    #print(classification_report(y_test,y_pred))

print("All")    
print(get_results(subject_to_data, 0, 100))

print("20 to 30")    
print(get_results(subject_to_data, 20, 30))

print("30 to 40")    
print(get_results(subject_to_data, 30, 40))

print("40 to 50")    
print(get_results(subject_to_data, 40, 50))

print("50 to 60")    
print(get_results(subject_to_data, 50, 60))
# Out:
# All
# (0.6068181818181818, 0.1554950771190666)
# 20 to 30
# (0.6666666666666667, 0.15811388300841897)
# 30 to 40
# (0.6666666666666666, 0.31622776601683794)
# 40 to 50
# (0.4333333333333333, 0.3511884584284246)
# 50 to 60
# (0.6333333333333333, 0.4068851871911235)

# %%
## K-means clustering
def k_means_get_results(subject_to_data, min_age, max_age):
    X = []
    y = []
    for pid, l in subject_to_data.items():
        if(l[0] >= min_age and l[0] < max_age):
            #X.append(l[2].flatten())
            X.append(l[3])
            y.append(int(l[1]))

    X = np.array(X)
    y = np.array(y)
    
    kmeans = GaussianMixture(n_components=5, covariance_type='diag').fit(X)
    y_kmeans = kmeans.predict(X)
    b2 = kmeans.predict_proba(X)
    
    kf = KFold(n_splits=10, shuffle=False)
    kf.get_n_splits(b2)
    
    acc = []
    for train_index, test_index in kf.split(b2):
        X_train, X_test = b2[train_index], b2[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        svclassifier = SVC(kernel='linear')
        svclassifier.fit(X_train, y_train)
        y_pred = svclassifier.predict(X_test)
        acc.append(accuracy_score(y_test, y_pred))
    
    acc = np.array(acc)
    return (np.mean(acc), np.std(acc))

# %%
print("All")    
print(k_means_get_results(subject_to_data, 0, 100))

print("20 to 30")    
print(k_means_get_results(subject_to_data, 20, 30))

print("30 to 40")    
print(k_means_get_results(subject_to_data, 30, 40))

print("40 to 50")    
print(k_means_get_results(subject_to_data, 40, 50))

print("50 to 60")    
print(k_means_get_results(subject_to_data, 50, 60))
# Out:
# All
# (0.5522727272727274, 0.13084147033003993)
# 20 to 30
# (0.475, 0.3051638903933426)
# 30 to 40
# (0.6, 0.43588989435406733)
# 40 to 50
# (0.4666666666666666, 0.3559026084010437)
# 50 to 60
# (0.55, 0.2891558595482912)

# %%
#t-SNE before k-means clustering
def tsne_k_means_get_results(subject_to_data, min_age, max_age):
    X = []
    y = []
    for pid, l in subject_to_data.items():
        if(l[0] >= min_age and l[0] < max_age):
            X.append(l[2].flatten())
            #X.append(l[3])
            y.append(int(l[1]))

    X = np.array(X)
    y = np.array(y)
    
    X = TSNE(n_components=2).fit_transform(X)
    
    kmeans = GaussianMixture(n_components=5, covariance_type='diag').fit(X)
    y_kmeans = kmeans.predict(X)
    b2 = kmeans.predict_proba(X)
    
    kf = KFold(n_splits=5, shuffle=True)
    kf.get_n_splits(b2)
    
    acc = []
    for train_index, test_index in kf.split(b2):
        X_train, X_test = b2[train_index], b2[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        svclassifier = SVC(kernel='linear')
        svclassifier.fit(X_train, y_train)
        y_pred = svclassifier.predict(X_test)
        acc.append(accuracy_score(y_test, y_pred))
    
    acc = np.array(acc)
    return (np.mean(acc), np.std(acc))

# %%
print("All")    
print(tsne_k_means_get_results(subject_to_data, 0, 100))

print("20 to 30")    
print(k_means_get_results(subject_to_data, 20, 30))

print("30 to 40")    
print(k_means_get_results(subject_to_data, 30, 40))

print("40 to 50")    
print(k_means_get_results(subject_to_data, 40, 50))

print("50 to 60")    
print(k_means_get_results(subject_to_data, 50, 60))
# Out:
# All
# (0.650197628458498, 0.10412600689580623)
# 20 to 30
# (0.6666666666666667, 0.27386127875258304)
# 30 to 40
# (0.75, 0.33541019662496846)
# 40 to 50
# (0.36666666666666664, 0.39999999999999997)
# 50 to 60
# (0.2333333333333333, 0.2603416558635551)

# %% [markdown]
# ## Convolutional Neural Networks

# %%
class ConvModel(Module):
    def __init__(self):
        super(ConvModel, self).__init__()
        self.a1 = Conv2d(1, 4, kernel_size=3, stride=1, padding=1)
        self.a2 =BatchNorm2d(4)
        self.a3 = ReLU(inplace=True)
        self.a4 = MaxPool2d(kernel_size=2, stride=2)
        self.a5 = Conv2d(4, 4, kernel_size=3, stride=1, padding=1)
        self.a6 = BatchNorm2d(4)
        self.a7 = ReLU(inplace=True)
        self.a8 = MaxPool2d(kernel_size=2, stride=2)

        self.linear_layers = Sequential(
            Linear(4 * 64 * 64, 2)
        )

    def forward(self, x):
        print(x.shape)
        x = self.a1(x)
        x = self.a2(x)
        x = self.a3(x)
        x = self.a4(x)
        x = self.a5(x)
        x = self.a6(x)
        x = self.a7(x)
        x = self.a8(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        return x

# %%
def train(epoch):
    model.train()
    tr_loss = 0
    # getting the training set
    x_train, y_train = Variable(train_x.double()), Variable(train_y.long())
    #x_train = torch.from_numpy(x_train)
    #y_train = torch.from_numpy(y_train)
    # getting the validation set
    x_val, y_val = Variable(val_x), Variable(val_y)
    # converting the data into GPU format
    
    # clearing the Gradients of the model parameters
    optimizer.zero_grad()
    
    # prediction for training and validation set
    output_train = model(x_train.double())
    output_val = model(x_val.double())

    # computing the training and validation loss
    loss_train = criterion(output_train, y_train.long())
    loss_val = criterion(output_val, y_val.long())
    train_losses.append(loss_train)
    val_losses.append(loss_val)

    # computing the updated weights of all the model parameters
    loss_train.backward()
    optimizer.step()
    tr_loss = loss_train.item()
    if epoch%2 == 0:
        # printing the validation loss
        print('Epoch : ',epoch+1, '\t', 'loss :', loss_val)

# %%
model = ConvModel()
optimizer = Adam(model.parameters(), lr=0.07)
criterion = CrossEntropyLoss()
model = model.double()  
print(model)
# defining the number of epochs
n_epochs = 50
# empty list to store training losses
train_losses = []
# empty list to store validation losses
val_losses = []
# training the model
for epoch in range(n_epochs):
    train(epoch)
    
# plotting the training and validation loss
plt.plot(train_losses, label='Training loss')
plt.plot(val_losses, label='Validation loss')
plt.legend()
plt.show()

with torch.no_grad():
    output = model(train_x.cpu().double())
    
softmax = torch.exp(output.cpu())
prob = softmax.numpy()
predictions = np.argmax(prob, axis=1)

# accuracy on training set
print(accuracy_score(train_y, predictions))

with torch.no_grad():
    output = model(val_x.cpu().double())

softmax = torch.exp(output).cpu()
prob = softmax.numpy()
predictions = np.argmax(prob, axis=1)

# accuracy on validation set
print(accuracy_score(val_y, predictions))
# Out:
# ConvModel(
#   (a1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (a2): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (a3): ReLU(inplace=True)
#   (a4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (a5): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (a6): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (a7): ReLU(inplace=True)
#   (a8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (linear_layers): Sequential(
#     (0): Linear(in_features=16384, out_features=2, bias=True)
#   )
# )
# torch.Size([102, 1, 256, 256])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-7fb91450611a> in <module>
#      12 # training the model
#      13 for epoch in range(n_epochs):
# ---> 14     train(epoch)
#      15
#      16 # plotting the training and validation loss
#
# <ipython-input-59-d30828bd528b> in train(epoch)
#      14
#      15     # prediction for training and validation set
# ---> 16     output_train = model(x_train.double())
#      17     output_val = model(x_val.double())
#      18
#
# /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-55-47ce66744b75> in forward(self, x)
#      17     def forward(self, x):
#      18         print(x.shape)
# ---> 19         input()
#      20         x = self.a1(x)
#      21         x = self.a2(x)
#
# /usr/local/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     855                 "raw_input was called, but this frontend does not support input requests."
#     856             )
# --> 857         return self._input_request(str(prompt),
#     858             self._parent_ident,
#     859             self._parent_header,
#
# /usr/local/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     899             except KeyboardInterrupt:
#     900                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 901                 raise KeyboardInterrupt("Interrupted by user") from None
#     902             except Exception as e:
#     903                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Model Agnostic Meta-Learning

# %%
class MetaConvModel(MetaModule):
    def __init__(self):
        super(MetaConvModel, self).__init__()
        self.a1 = MetaConv2d(1, 4, kernel_size=3, stride=1, padding=1)
        self.a2 = MetaBatchNorm2d(4)
        self.a3 = ReLU(inplace=True)
        self.a4 = MaxPool2d(kernel_size=2, stride=2)
        self.a5 = MetaConv2d(4, 4, kernel_size=3, stride=1, padding=1)
        self.a6 = MetaBatchNorm2d(4)
        self.a7 = ReLU(inplace=True)
        self.a8 = MaxPool2d(kernel_size=2, stride=2)

        self.linear_layers = MetaSequential(
            MetaLinear(4 * 64 * 64, 2)
        )

    def forward(self, x):
        x = self.a1(x)
        x = self.a2(x)
        x = self.a3(x)
        x = self.a4(x)
        x = self.a5(x)
        x = self.a6(x)
        x = self.a7(x)
        x = self.a8(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        return x

# %%
"""
import random
import os
# Export data
folder = "./training_data"
for pid, l in subject_to_data.items():
    x_temp = cv2.resize(l[2]*255, dsize=(100, 100), interpolation=cv2.INTER_CUBIC)
    # AGE is l[0]
    category = int(l[0] / 10) - 2 
    tmp = str(int(l[1]))
    r = random.randint(0, 1000)
    path = "./training_data/" + str(category) + "/" + tmp + "/" + str(r) + ".png"
    print(path)
    cv2.imwrite(path, x_temp)
"""

# %%
"""
list = []
for i in range(4):
    for j in range(2):
        new_item = [str(i), str(j)]
        list.append(new_item)
        
import json

jsonString = json.dumps(list)
print(jsonString)
"""

# %%
"""
from torchmeta.datasets import Omniglot, MiniImagenet

meta_train_dataset = Omniglot("./test2",
                                use_vinyals_split=True,
                                num_classes_per_task=2,
                                meta_train=True)

meta_val_dataset = Omniglot("./test2",
                            use_vinyals_split=True,
                            num_classes_per_task=2,
                            meta_val=True,
                            )

meta_test_dataset = Omniglot("./test2",
                            use_vinyals_split=True,
                            num_classes_per_task=2,
                            meta_test=True,
                            )

meta_train_dataloader = BatchMetaDataLoader(meta_train_dataset,
                                            batch_size=5,
                                            shuffle=False)
meta_val_dataloader = BatchMetaDataLoader(meta_val_dataset,
                                            batch_size=1,
                                              shuffle=False)
                                              """

# %%
model = MetaConvModel()
optimizer = Adam(model.parameters(), lr=0.07)
criterion = CrossEntropyLoss()

metalearner = ModelAgnosticMetaLearning(model,
                            optimizer,
                            first_order=False,
                            num_adaptation_steps=1,
                            step_size=.1,
                            loss_function=criterion,
                            device="cpu")

r = []
inner_losses = []
outer_losses = []
mean_outer_losses = []
accuracies_before = []
accuracies_after = []

for epoch in range(100):
    results = metalearner.train(e)
    print(results)
    r.append(results)
    inner_losses.append(results["inner_losses"])
    outer_losses.append(results["outer_losses"])
    mean_outer_losses.append(results["mean_outer_loss"])
    accuracies_before.append(results["accuracies_before"])
    accuracies_after.append(results["accuracies_after"])
#results = metalearner.evaluate(val_x)
# Out:
# {'num_tasks': 4, 'inner_losses': array([[0.72650844, 0.787144  , 0.7812835 , 0.69371945]], dtype=float32), 'outer_losses': array([0.55888087, 0.9779886 , 0.95309687, 0.5728436 ], dtype=float32), 'mean_outer_loss': 0.765702486038208, 'accuracies_before': array([0.51282054, 0.47619048, 0.33333334, 0.53846157], dtype=float32), 'accuracies_after': array([0.75     , 0.4      , 0.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[726.97736, 532.4404 , 386.7276 , 795.14594]], dtype=float32), 'outer_losses': array([ 732.28235,  340.86505,    0.     , 1169.884  ], dtype=float32), 'mean_outer_loss': 560.7578125, 'accuracies_before': array([0.43589744, 0.61904764, 0.6666667 , 0.42307693], dtype=float32), 'accuracies_after': array([0.375     , 0.8       , 1.        , 0.16666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[343.8763 , 243.28227, 169.99951, 375.8045 ]], dtype=float32), 'outer_losses': array([267.77646, 181.25835,   0.     , 524.23114], dtype=float32), 'mean_outer_loss': 243.31649780273438, 'accuracies_before': array([0.43589744, 0.61904764, 0.6666667 , 0.42307693], dtype=float32), 'accuracies_after': array([0.375     , 0.8       , 1.        , 0.16666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[21.77642 , 12.290577,  8.657149, 31.147572]], dtype=float32), 'outer_losses': array([ 8.41264  , 20.033083 ,  2.3552907,  5.5278306], dtype=float32), 'mean_outer_loss': 9.082210540771484, 'accuracies_before': array([0.51282054, 0.5714286 , 0.6666667 , 0.53846157], dtype=float32), 'accuracies_after': array([0.75     , 0.6      , 0.6      , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[ 83.85179,  97.02132, 134.17694,  93.37044]], dtype=float32), 'outer_losses': array([ 47.294426, 162.51724 , 198.4932  ,  26.987852], dtype=float32), 'mean_outer_loss': 108.82318115234375, 'accuracies_before': array([0.5641026 , 0.42857143, 0.33333334, 0.5769231 ], dtype=float32), 'accuracies_after': array([0.75     , 0.2      , 0.       , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[63.592873, 61.606598, 94.423195, 68.37539 ]], dtype=float32), 'outer_losses': array([ 28.181437,  99.353806, 129.40706 ,  16.663095], dtype=float32), 'mean_outer_loss': 68.40135192871094, 'accuracies_before': array([0.5641026 , 0.3809524 , 0.33333334, 0.5769231 ], dtype=float32), 'accuracies_after': array([0.625    , 0.2      , 0.       , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[24.26123 , 10.735186, 12.604334, 23.522991]], dtype=float32), 'outer_losses': array([1.3580189e+01, 1.4543481e-06, 0.0000000e+00, 4.3588351e-02],
#       dtype=float32), 'mean_outer_loss': 3.405944585800171, 'accuracies_before': array([0.41025642, 0.71428573, 0.6666667 , 0.42307693], dtype=float32), 'accuracies_after': array([0.375, 1.   , 1.   , 1.   ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[65.14021 , 36.34584 , 31.374378, 64.03985 ]], dtype=float32), 'outer_losses': array([47.88512 , 20.961798,  0.      , 42.63441 ], dtype=float32), 'mean_outer_loss': 27.870330810546875, 'accuracies_before': array([0.43589744, 0.6666667 , 0.6666667 , 0.46153846], dtype=float32), 'accuracies_after': array([0.375     , 0.8       , 1.        , 0.16666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[67.4968  , 37.462627, 31.533785, 66.640305]], dtype=float32), 'outer_losses': array([46.260662, 23.641714,  0.      , 47.0348  ], dtype=float32), 'mean_outer_loss': 29.234294891357422, 'accuracies_before': array([0.43589744, 0.6666667 , 0.6666667 , 0.42307693], dtype=float32), 'accuracies_after': array([0.375     , 0.8       , 1.        , 0.16666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[47.180965, 25.121454, 20.788609, 45.855473]], dtype=float32), 'outer_losses': array([26.226013, 10.246371,  0.      , 16.702589], dtype=float32), 'mean_outer_loss': 13.293743133544922, 'accuracies_before': array([0.43589744, 0.6666667 , 0.6666667 , 0.46153846], dtype=float32), 'accuracies_after': array([0.375, 0.8  , 1.   , 0.5  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[21.79997  ,  9.459721 ,  7.2055345, 19.666777 ]], dtype=float32), 'outer_losses': array([2.8999965e+00, 4.4822191e-06, 0.0000000e+00, 3.6931448e-05],
#       dtype=float32), 'mean_outer_loss': 0.7250095009803772, 'accuracies_before': array([0.3846154 , 0.71428573, 0.71428573, 0.46153846], dtype=float32), 'accuracies_after': array([0.625, 1.   , 1.   , 1.   ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[11.389537 ,  4.504775 ,  3.9667068, 11.000275 ]], dtype=float32), 'outer_losses': array([1.1695709, 7.6837745, 2.1901362, 3.9113102], dtype=float32), 'mean_outer_loss': 3.7386980056762695, 'accuracies_before': array([0.61538464, 0.5714286 , 0.6666667 , 0.5       ], dtype=float32), 'accuracies_after': array([0.875    , 0.6      , 0.6      , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[15.407117, 12.402142, 14.39604 , 17.699734]], dtype=float32), 'outer_losses': array([ 4.2240524, 23.22459  , 12.865659 ,  5.4818654], dtype=float32), 'mean_outer_loss': 11.449041366577148, 'accuracies_before': array([0.61538464, 0.47619048, 0.47619048, 0.5769231 ], dtype=float32), 'accuracies_after': array([0.75     , 0.2      , 0.2      , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[16.358583, 13.133037, 15.625408, 17.856722]], dtype=float32), 'outer_losses': array([ 3.7626572, 22.057676 , 14.051437 ,  4.470042 ], dtype=float32), 'mean_outer_loss': 11.085453033447266, 'accuracies_before': array([0.5641026 , 0.47619048, 0.42857143, 0.53846157], dtype=float32), 'accuracies_after': array([0.75     , 0.2      , 0.2      , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[11.813187 ,  7.7058163,  8.710285 , 12.969721 ]], dtype=float32), 'outer_losses': array([1.1504861, 9.970695 , 5.1058083, 2.045705 ], dtype=float32), 'mean_outer_loss': 4.568173408508301, 'accuracies_before': array([0.5897436 , 0.47619048, 0.52380955, 0.5769231 ], dtype=float32), 'accuracies_after': array([0.75     , 0.2      , 0.2      , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[8.064748 , 3.179455 , 2.3958957, 7.0182905]], dtype=float32), 'outer_losses': array([0.6248638 , 1.7045463 , 0.0772221 , 0.01616734], dtype=float32), 'mean_outer_loss': 0.605699896812439, 'accuracies_before': array([0.41025642, 0.5714286 , 0.52380955, 0.42307693], dtype=float32), 'accuracies_after': array([0.75, 0.8 , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[9.627302 , 4.621607 , 2.8788738, 7.188563 ]], dtype=float32), 'outer_losses': array([5.2532101e+00, 3.5759589e-05, 7.4623786e-06, 3.0210397e+00],
#       dtype=float32), 'mean_outer_loss': 2.068573236465454, 'accuracies_before': array([0.41025642, 0.6666667 , 0.71428573, 0.5       ], dtype=float32), 'accuracies_after': array([0.375    , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[11.241712 ,  6.0485334,  4.2526956,  9.012755 ]], dtype=float32), 'outer_losses': array([8.1901121e+00, 0.0000000e+00, 2.3841856e-08, 5.6575680e+00],
#       dtype=float32), 'mean_outer_loss': 3.4619200229644775, 'accuracies_before': array([0.3846154 , 0.61904764, 0.6666667 , 0.53846157], dtype=float32), 'accuracies_after': array([0.375    , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[11.757301 ,  7.156816 ,  5.152886 , 10.3234825]], dtype=float32), 'outer_losses': array([9.065071  , 0.01016519, 0.        , 9.814107  ], dtype=float32), 'mean_outer_loss': 4.7223358154296875, 'accuracies_before': array([0.41025642, 0.6666667 , 0.6666667 , 0.5       ], dtype=float32), 'accuracies_after': array([0.375     , 1.        , 1.        , 0.33333334], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[11.293368 ,  7.1495447,  5.0542994, 10.320129 ]], dtype=float32), 'outer_losses': array([ 8.094279 ,  1.5890341,  0.       , 10.74957  ], dtype=float32), 'mean_outer_loss': 5.108221054077148, 'accuracies_before': array([0.41025642, 0.6666667 , 0.6666667 , 0.46153846], dtype=float32), 'accuracies_after': array([0.375     , 0.8       , 1.        , 0.33333334], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[9.441435, 6.014559, 4.131995, 8.710295]], dtype=float32), 'outer_losses': array([5.6592026e+00, 1.5105319e+00, 7.1525562e-08, 8.2518234e+00],
#       dtype=float32), 'mean_outer_loss': 3.8553895950317383, 'accuracies_before': array([0.41025642, 0.6666667 , 0.6666667 , 0.46153846], dtype=float32), 'accuracies_after': array([0.375     , 0.8       , 1.        , 0.33333334], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[6.853147 , 4.1029015, 2.6838925, 6.1445904]], dtype=float32), 'outer_losses': array([2.2289982e+00, 3.5818931e-02, 5.1736324e-06, 3.3482685e+00],
#       dtype=float32), 'mean_outer_loss': 1.4032727479934692, 'accuracies_before': array([0.3846154 , 0.6666667 , 0.6666667 , 0.53846157], dtype=float32), 'accuracies_after': array([0.375, 1.   , 1.   , 0.5  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[4.5545216, 2.2541645, 1.2425709, 3.7922335]], dtype=float32), 'outer_losses': array([0.2133877 , 0.0006216 , 0.00052919, 0.43069366], dtype=float32), 'mean_outer_loss': 0.16130802035331726, 'accuracies_before': array([0.41025642, 0.61904764, 0.71428573, 0.5769231 ], dtype=float32), 'accuracies_after': array([1.       , 1.       , 1.       , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.2756615 , 1.586796  , 0.67525476, 2.9266915 ]], dtype=float32), 'outer_losses': array([1.756414  , 0.4614849 , 0.03912514, 0.2416531 ], dtype=float32), 'mean_outer_loss': 0.6246693134307861, 'accuracies_before': array([0.53846157, 0.5714286 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([0.75     , 0.8      , 1.       , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.6277728, 2.6006322, 1.8251516, 3.4970312]], dtype=float32), 'outer_losses': array([3.0805674, 2.187772 , 0.446839 , 1.2045807], dtype=float32), 'mean_outer_loss': 1.7299396991729736, 'accuracies_before': array([0.53846157, 0.5714286 , 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([0.75     , 0.4      , 0.6      , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[4.1443586, 3.221453 , 2.752452 , 3.9281828]], dtype=float32), 'outer_losses': array([3.505703  , 3.297889  , 0.77678806, 1.530646  ], dtype=float32), 'mean_outer_loss': 2.277756452560425, 'accuracies_before': array([0.5897436 , 0.5714286 , 0.5714286 , 0.53846157], dtype=float32), 'accuracies_after': array([0.75     , 0.4      , 0.6      , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[4.0484195, 3.0911095, 2.847411 , 3.8090298]], dtype=float32), 'outer_losses': array([3.1727977, 2.7179928, 0.5554454, 1.2627287], dtype=float32), 'mean_outer_loss': 1.9272410869598389, 'accuracies_before': array([0.5897436 , 0.52380955, 0.5714286 , 0.53846157], dtype=float32), 'accuracies_after': array([0.75     , 0.4      , 0.6      , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.5224953, 2.4395351, 2.405188 , 3.324753 ]], dtype=float32), 'outer_losses': array([2.3353927 , 1.2071105 , 0.16827346, 0.5945043 ], dtype=float32), 'mean_outer_loss': 1.0763202905654907, 'accuracies_before': array([0.5641026 , 0.52380955, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([0.75     , 0.6      , 1.       , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.1071413, 1.8709371, 2.002818 , 2.893852 ]], dtype=float32), 'outer_losses': array([1.3214724 , 0.23771831, 0.03073752, 0.03947045], dtype=float32), 'mean_outer_loss': 0.40734967589378357, 'accuracies_before': array([0.4871795 , 0.61904764, 0.5714286 , 0.5769231 ], dtype=float32), 'accuracies_after': array([0.75, 0.8 , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.081709 , 1.827283 , 1.8033673, 2.7707977]], dtype=float32), 'outer_losses': array([0.5117139 , 0.00947603, 0.00649917, 0.08837003], dtype=float32), 'mean_outer_loss': 0.15401479601860046, 'accuracies_before': array([0.33333334, 0.6666667 , 0.52380955, 0.42307693], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.2275186, 2.0220523, 1.624837 , 2.8465908]], dtype=float32), 'outer_losses': array([4.9215111e-01, 4.3712347e-04, 2.0633028e-03, 5.3812528e-01],
#       dtype=float32), 'mean_outer_loss': 0.2581942081451416, 'accuracies_before': array([0.33333334, 0.61904764, 0.52380955, 0.46153846], dtype=float32), 'accuracies_after': array([0.75     , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.3910413, 2.1756353, 1.4733477, 2.9094722]], dtype=float32), 'outer_losses': array([1.0431248e+00, 5.3638279e-05, 1.0720943e-03, 1.0481129e+00],
#       dtype=float32), 'mean_outer_loss': 0.5230908989906311, 'accuracies_before': array([0.41025642, 0.61904764, 0.52380955, 0.46153846], dtype=float32), 'accuracies_after': array([0.375    , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.4544146, 2.2273266, 1.3868796, 2.900172 ]], dtype=float32), 'outer_losses': array([1.4898567e+00, 1.7308621e-05, 8.3382812e-04, 1.3526479e+00],
#       dtype=float32), 'mean_outer_loss': 0.7108389139175415, 'accuracies_before': array([0.41025642, 0.61904764, 0.61904764, 0.5       ], dtype=float32), 'accuracies_after': array([0.375    , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.3868337, 2.2030392, 1.3284727, 2.8098273]], dtype=float32), 'outer_losses': array([1.6483204e+00, 1.2850469e-05, 9.1261847e-04, 1.4255515e+00],
#       dtype=float32), 'mean_outer_loss': 0.7686994075775146, 'accuracies_before': array([0.41025642, 0.6666667 , 0.6666667 , 0.5       ], dtype=float32), 'accuracies_after': array([0.375    , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[3.2119818, 2.1182795, 1.2693182, 2.6330283]], dtype=float32), 'outer_losses': array([1.5532384e+00, 1.8667579e-05, 1.3313380e-03, 1.2700344e+00],
#       dtype=float32), 'mean_outer_loss': 0.7061557173728943, 'accuracies_before': array([0.41025642, 0.61904764, 0.6666667 , 0.5       ], dtype=float32), 'accuracies_after': array([0.375    , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.9720783, 1.9970187, 1.2236577, 2.3946712]], dtype=float32), 'outer_losses': array([1.2846435e+00, 4.4604785e-05, 2.3577481e-03, 9.5100230e-01],
#       dtype=float32), 'mean_outer_loss': 0.5595120191574097, 'accuracies_before': array([0.41025642, 0.61904764, 0.61904764, 0.5       ], dtype=float32), 'accuracies_after': array([0.375    , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.7110968, 1.8634814, 1.2118646, 2.1286678]], dtype=float32), 'outer_losses': array([9.3733549e-01, 1.4887910e-04, 4.6115867e-03, 5.7493246e-01],
#       dtype=float32), 'mean_outer_loss': 0.37925711274147034, 'accuracies_before': array([0.3846154 , 0.61904764, 0.5714286 , 0.53846157], dtype=float32), 'accuracies_after': array([0.375    , 1.       , 1.       , 0.6666667], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.4690373, 1.737046 , 1.2464926, 1.8705275]], dtype=float32), 'outer_losses': array([6.1773086e-01, 5.8069744e-04, 9.2451749e-03, 2.6674300e-01],
#       dtype=float32), 'mean_outer_loss': 0.2235749363899231, 'accuracies_before': array([0.41025642, 0.61904764, 0.52380955, 0.5       ], dtype=float32), 'accuracies_after': array([0.5      , 1.       , 1.       , 0.8333333], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.2782152, 1.6373965, 1.3239946, 1.6653666]], dtype=float32), 'outer_losses': array([0.40433276, 0.00227404, 0.01782286, 0.09711192], dtype=float32), 'mean_outer_loss': 0.1303853988647461, 'accuracies_before': array([0.3846154 , 0.6666667 , 0.52380955, 0.53846157], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.1620905, 1.5722438, 1.4241049, 1.546091 ]], dtype=float32), 'outer_losses': array([0.3156698 , 0.00798607, 0.03165741, 0.03273578], dtype=float32), 'mean_outer_loss': 0.09701226651668549, 'accuracies_before': array([0.33333334, 0.6666667 , 0.5714286 , 0.5       ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.106982 , 1.5429189, 1.5296084, 1.5005279]], dtype=float32), 'outer_losses': array([0.31761163, 0.02328981, 0.05132339, 0.01340765], dtype=float32), 'mean_outer_loss': 0.10140811651945114, 'accuracies_before': array([0.46153846, 0.7619048 , 0.5714286 , 0.53846157], dtype=float32), 'accuracies_after': array([0.875, 1.   , 1.   , 1.   ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.0897205, 1.5576217, 1.6273558, 1.4980872]], dtype=float32), 'outer_losses': array([0.36636156, 0.05463041, 0.07593222, 0.00983327], dtype=float32), 'mean_outer_loss': 0.1266893595457077, 'accuracies_before': array([0.53846157, 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.0875123, 1.6543915, 1.7056643, 1.510322 ]], dtype=float32), 'outer_losses': array([0.4252661 , 0.10136745, 0.10305228, 0.01344081], dtype=float32), 'mean_outer_loss': 0.1607816517353058, 'accuracies_before': array([0.51282054, 0.6666667 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.080314 , 1.7621689, 1.756166 , 1.5167133]], dtype=float32), 'outer_losses': array([0.47054505, 0.14948277, 0.1287205 , 0.02062699], dtype=float32), 'mean_outer_loss': 0.1923438310623169, 'accuracies_before': array([0.5641026 , 0.71428573, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.0577304, 1.8338557, 1.773581 , 1.5079093]], dtype=float32), 'outer_losses': array([0.49032626, 0.18185852, 0.14733937, 0.0275408 ], dtype=float32), 'mean_outer_loss': 0.21176624298095703, 'accuracies_before': array([0.53846157, 0.6666667 , 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.0174387, 1.8653127, 1.7567486, 1.4766368]], dtype=float32), 'outer_losses': array([0.4830168 , 0.188562  , 0.15525827, 0.03057417], dtype=float32), 'mean_outer_loss': 0.2143528163433075, 'accuracies_before': array([0.53846157, 0.6666667 , 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([0.75, 0.8 , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.9616623, 1.8600416, 1.709756 , 1.423942 ]], dtype=float32), 'outer_losses': array([0.45266348, 0.17071736, 0.15194048, 0.02882839], dtype=float32), 'mean_outer_loss': 0.2010374218225479, 'accuracies_before': array([0.53846157, 0.6666667 , 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.8973734, 1.8251628, 1.6407235, 1.3563507]], dtype=float32), 'outer_losses': array([0.40779608, 0.13779086, 0.14030118, 0.02389341], dtype=float32), 'mean_outer_loss': 0.17744538187980652, 'accuracies_before': array([0.5641026 , 0.71428573, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.8329773, 1.77209  , 1.5585363, 1.2831739]], dtype=float32), 'outer_losses': array([0.35785156, 0.10118446, 0.12462852, 0.01827788], dtype=float32), 'mean_outer_loss': 0.15048560500144958, 'accuracies_before': array([0.53846157, 0.71428573, 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([0.75, 1.  , 1.  , 1.  ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7761266, 1.7098318, 1.4722815, 1.2133386]], dtype=float32), 'outer_losses': array([0.3123266 , 0.0693976 , 0.10822491, 0.01367355], dtype=float32), 'mean_outer_loss': 0.12590566277503967, 'accuracies_before': array([0.53846157, 0.71428573, 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([0.875, 1.   , 1.   , 1.   ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7309369, 1.6459104, 1.3884809, 1.1537014]], dtype=float32), 'outer_losses': array([0.27721378, 0.04573562, 0.09281318, 0.01078773], dtype=float32), 'mean_outer_loss': 0.10663758218288422, 'accuracies_before': array([0.5641026 , 0.71428573, 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([0.875, 1.   , 1.   , 1.   ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6993561, 1.5852854, 1.3115159, 1.107754 ]], dtype=float32), 'outer_losses': array([0.25546753, 0.0297246 , 0.0793511 , 0.00960694], dtype=float32), 'mean_outer_loss': 0.09353753924369812, 'accuracies_before': array([0.53846157, 0.71428573, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([0.875, 1.   , 1.   , 1.   ], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6809798, 1.5310732, 1.2437464, 1.0762118]], dtype=float32), 'outer_losses': array([0.24680233, 0.01948243, 0.06807564, 0.00981964], dtype=float32), 'mean_outer_loss': 0.08604501187801361, 'accuracies_before': array([0.5641026 , 0.71428573, 0.5714286 , 0.6923077 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6736611, 1.4837339, 1.1861755, 1.0574726]], dtype=float32), 'outer_losses': array([0.24894768, 0.01309059, 0.05889596, 0.01113545], dtype=float32), 'mean_outer_loss': 0.08301742374897003, 'accuracies_before': array([0.53846157, 0.6666667 , 0.5714286 , 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6745517, 1.4433995, 1.1388514, 1.0489194]], dtype=float32), 'outer_losses': array([0.25829777, 0.00911128, 0.05157151, 0.01329164], dtype=float32), 'mean_outer_loss': 0.08306805044412613, 'accuracies_before': array([0.4871795 , 0.61904764, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6807556, 1.4095834, 1.1008475, 1.047618 ]], dtype=float32), 'outer_losses': array([0.27143657, 0.0066065 , 0.04582854, 0.01598716], dtype=float32), 'mean_outer_loss': 0.08496470004320145, 'accuracies_before': array([0.46153846, 0.61904764, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6895243, 1.3816156, 1.0710671, 1.0507411]], dtype=float32), 'outer_losses': array([0.2852366 , 0.00500959, 0.04141034, 0.01887937], dtype=float32), 'mean_outer_loss': 0.08763396739959717, 'accuracies_before': array([0.46153846, 0.61904764, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6986634, 1.3587255, 1.048316 , 1.0559186]], dtype=float32), 'outer_losses': array([0.29695454, 0.00398225, 0.03810112, 0.02159096], dtype=float32), 'mean_outer_loss': 0.09015722572803497, 'accuracies_before': array([0.46153846, 0.61904764, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7066848, 1.3400147, 1.0314969, 1.0613284]], dtype=float32), 'outer_losses': array([0.3047203 , 0.00332006, 0.03571898, 0.02375018], dtype=float32), 'mean_outer_loss': 0.09187738597393036, 'accuracies_before': array([0.46153846, 0.61904764, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7126154, 1.3246732, 1.0196018, 1.0656117]], dtype=float32), 'outer_losses': array([0.30732316, 0.00289997, 0.03412884, 0.02506477], dtype=float32), 'mean_outer_loss': 0.0923541858792305, 'accuracies_before': array([0.46153846, 0.61904764, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7159481, 1.3117044, 1.0119245, 1.0682735]], dtype=float32), 'outer_losses': array([0.30422792, 0.00264605, 0.03320891, 0.02539457], dtype=float32), 'mean_outer_loss': 0.09136936068534851, 'accuracies_before': array([0.46153846, 0.61904764, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7166275, 1.3006333, 1.0079756, 1.0689698]], dtype=float32), 'outer_losses': array([0.2956888 , 0.00251326, 0.03286295, 0.02476259], dtype=float32), 'mean_outer_loss': 0.08895690739154816, 'accuracies_before': array([0.46153846, 0.61904764, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7147634, 1.2899859, 1.0069708, 1.0676396]], dtype=float32), 'outer_losses': array([0.2824809 , 0.00247604, 0.03301531, 0.02329997], dtype=float32), 'mean_outer_loss': 0.08531805872917175, 'accuracies_before': array([0.46153846, 0.61904764, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.710951 , 1.2791045, 1.0081838, 1.0650028]], dtype=float32), 'outer_losses': array([0.26595527, 0.00251583, 0.03359831, 0.02127923], dtype=float32), 'mean_outer_loss': 0.08083716034889221, 'accuracies_before': array([0.46153846, 0.61904764, 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7060825, 1.2678398, 1.0113262, 1.0611509]], dtype=float32), 'outer_losses': array([0.24747607, 0.00261866, 0.03454898, 0.01896407], dtype=float32), 'mean_outer_loss': 0.07590194046497345, 'accuracies_before': array([0.4871795 , 0.6666667 , 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7005439, 1.2560405, 1.0155646, 1.0573676]], dtype=float32), 'outer_losses': array([0.22830757, 0.00277476, 0.03580891, 0.01655962], dtype=float32), 'mean_outer_loss': 0.07086271792650223, 'accuracies_before': array([0.51282054, 0.6666667 , 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6950656, 1.2430853, 1.0204887, 1.0548702]], dtype=float32), 'outer_losses': array([0.20981197, 0.00297815, 0.0373426 , 0.01426982], dtype=float32), 'mean_outer_loss': 0.06610063463449478, 'accuracies_before': array([0.51282054, 0.6666667 , 0.61904764, 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6901517, 1.2292128, 1.0254233, 1.0539392]], dtype=float32), 'outer_losses': array([0.1928159 , 0.00322353, 0.03904771, 0.01224356], dtype=float32), 'mean_outer_loss': 0.06183267757296562, 'accuracies_before': array([0.53846157, 0.6666667 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6861817, 1.2146038, 1.0309079, 1.0547433]], dtype=float32), 'outer_losses': array([0.1777318 , 0.00350369, 0.04086023, 0.01049761], dtype=float32), 'mean_outer_loss': 0.0581483319401741, 'accuracies_before': array([0.53846157, 0.71428573, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6837763, 1.198773 , 1.036398 , 1.0565524]], dtype=float32), 'outer_losses': array([0.16477771, 0.00380077, 0.04270457, 0.00904732], dtype=float32), 'mean_outer_loss': 0.055082593113183975, 'accuracies_before': array([0.53846157, 0.71428573, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6826208, 1.1809638, 1.0411556, 1.0599734]], dtype=float32), 'outer_losses': array([0.15408072, 0.00409833, 0.04450347, 0.00789269], dtype=float32), 'mean_outer_loss': 0.052643805742263794, 'accuracies_before': array([0.53846157, 0.71428573, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6825951, 1.1630024, 1.0437711, 1.0645074]], dtype=float32), 'outer_losses': array([0.14521602, 0.00436876, 0.04613639, 0.00698201], dtype=float32), 'mean_outer_loss': 0.05067579448223114, 'accuracies_before': array([0.5897436 , 0.71428573, 0.5714286 , 0.5769231 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.68461  , 1.1453334, 1.0443888, 1.0706213]], dtype=float32), 'outer_losses': array([0.13789906, 0.00459435, 0.04752215, 0.00628377], dtype=float32), 'mean_outer_loss': 0.04907483235001564, 'accuracies_before': array([0.5897436 , 0.71428573, 0.5714286 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6882886, 1.128295 , 1.0425568, 1.0770371]], dtype=float32), 'outer_losses': array([0.13164917, 0.00475205, 0.04862086, 0.00574379], dtype=float32), 'mean_outer_loss': 0.0476914681494236, 'accuracies_before': array([0.5897436 , 0.71428573, 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6932508, 1.1122129, 1.037515 , 1.0845777]], dtype=float32), 'outer_losses': array([0.12634863, 0.00482381, 0.04930599, 0.00532447], dtype=float32), 'mean_outer_loss': 0.04645072668790817, 'accuracies_before': array([0.5897436 , 0.71428573, 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.6996808, 1.0985668, 1.0295382, 1.0917236]], dtype=float32), 'outer_losses': array([0.12180307, 0.00481223, 0.04956163, 0.00499157], dtype=float32), 'mean_outer_loss': 0.04529212415218353, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7074798, 1.0871416, 1.018844 , 1.098911 ]], dtype=float32), 'outer_losses': array([0.11764325, 0.00471116, 0.04941421, 0.00472119], dtype=float32), 'mean_outer_loss': 0.04412245750427246, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7159046, 1.0783304, 1.0047675, 1.1057832]], dtype=float32), 'outer_losses': array([0.11347924, 0.00453165, 0.04888644, 0.00449412], dtype=float32), 'mean_outer_loss': 0.04284786432981491, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7253637, 1.0728843, 0.987756 , 1.111883 ]], dtype=float32), 'outer_losses': array([0.10924195, 0.00427866, 0.04799255, 0.00429696], dtype=float32), 'mean_outer_loss': 0.04145252704620361, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7362176 , 1.0705111 , 0.96835154, 1.1178374 ]], dtype=float32), 'outer_losses': array([0.10497949, 0.00397002, 0.04679138, 0.00412138], dtype=float32), 'mean_outer_loss': 0.039965562522411346, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7485235 , 1.0710592 , 0.94660807, 1.124687  ]], dtype=float32), 'outer_losses': array([0.10071494, 0.00363124, 0.04532067, 0.00396199], dtype=float32), 'mean_outer_loss': 0.03840721398591995, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7619336 , 1.0745344 , 0.92237926, 1.1316785 ]], dtype=float32), 'outer_losses': array([0.09642743, 0.00327308, 0.04359052, 0.00381918], dtype=float32), 'mean_outer_loss': 0.0367775522172451, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.776402 , 1.0804235, 0.8957624, 1.1392095]], dtype=float32), 'outer_losses': array([0.09215883, 0.00291464, 0.04166429, 0.00369765], dtype=float32), 'mean_outer_loss': 0.03510885313153267, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.7921551 , 1.0886323 , 0.86728466, 1.1471455 ]], dtype=float32), 'outer_losses': array([0.08796661, 0.00256754, 0.03964544, 0.00359837], dtype=float32), 'mean_outer_loss': 0.033444490283727646, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.8082142, 1.0985041, 0.837175 , 1.1554663]], dtype=float32), 'outer_losses': array([0.08385522, 0.00224135, 0.03753863, 0.00352115], dtype=float32), 'mean_outer_loss': 0.031789086759090424, 'accuracies_before': array([0.61538464, 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.8246728 , 1.1094733 , 0.80609703, 1.1637422 ]], dtype=float32), 'outer_losses': array([0.08000883, 0.00194655, 0.03543371, 0.00346608], dtype=float32), 'mean_outer_loss': 0.030213795602321625, 'accuracies_before': array([0.61538464, 0.7619048 , 0.61904764, 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.8419526, 1.1215862, 0.7747047, 1.1729707]], dtype=float32), 'outer_losses': array([0.07639727, 0.00168466, 0.03338414, 0.00343201], dtype=float32), 'mean_outer_loss': 0.02872452139854431, 'accuracies_before': array([0.61538464, 0.7619048 , 0.6666667 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.8595446 , 1.1345725 , 0.74321055, 1.1829051 ]], dtype=float32), 'outer_losses': array([0.07306808, 0.00145445, 0.0314265 , 0.00341703], dtype=float32), 'mean_outer_loss': 0.027341516688466072, 'accuracies_before': array([0.5897436, 0.7619048, 0.7619048, 0.5769231], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.8775936, 1.1483799, 0.7121076, 1.1934508]], dtype=float32), 'outer_losses': array([0.07001004, 0.00125647, 0.02958459, 0.00341942], dtype=float32), 'mean_outer_loss': 0.02606762945652008, 'accuracies_before': array([0.5897436, 0.7619048, 0.7619048, 0.5769231], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.8957303, 1.163208 , 0.6815101, 1.2050592]], dtype=float32), 'outer_losses': array([0.06725706, 0.00108688, 0.02784869, 0.0034335 ], dtype=float32), 'mean_outer_loss': 0.02490653097629547, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.7619048 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.9136026 , 1.1784238 , 0.65218437, 1.2173523 ]], dtype=float32), 'outer_losses': array([0.06477668, 0.00094222, 0.02624231, 0.00345551], dtype=float32), 'mean_outer_loss': 0.023854181170463562, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.7619048 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.9313654 , 1.194055  , 0.62452924, 1.230778  ]], dtype=float32), 'outer_losses': array([0.06244659, 0.00082074, 0.02478561, 0.00348382], dtype=float32), 'mean_outer_loss': 0.02288419008255005, 'accuracies_before': array([0.5897436 , 0.7619048 , 0.7619048 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.9487158 , 1.2102283 , 0.59855664, 1.244527  ]], dtype=float32), 'outer_losses': array([0.06023965, 0.0007202 , 0.02344855, 0.00350492], dtype=float32), 'mean_outer_loss': 0.021978331729769707, 'accuracies_before': array([0.5897436 , 0.71428573, 0.7619048 , 0.61538464], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.9656996 , 1.2263132 , 0.57442963, 1.25943   ]], dtype=float32), 'outer_losses': array([0.05814794, 0.000636  , 0.0222266 , 0.00351806], dtype=float32), 'mean_outer_loss': 0.021132150664925575, 'accuracies_before': array([0.5897436 , 0.71428573, 0.7619048 , 0.65384614], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.9821478 , 1.2424493 , 0.55288523, 1.2750213 ]], dtype=float32), 'outer_losses': array([0.05609434, 0.00056485, 0.02112585, 0.00352334], dtype=float32), 'mean_outer_loss': 0.020327096804976463, 'accuracies_before': array([0.5897436 , 0.71428573, 0.7619048 , 0.65384614], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[1.9981271 , 1.2586435 , 0.53401804, 1.2906706 ]], dtype=float32), 'outer_losses': array([0.05410055, 0.00050515, 0.02013987, 0.00351843], dtype=float32), 'mean_outer_loss': 0.019565999507904053, 'accuracies_before': array([0.5897436 , 0.71428573, 0.8095238 , 0.65384614], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.013554 , 1.2745982, 0.5178539, 1.3060266]], dtype=float32), 'outer_losses': array([0.05213694, 0.00045511, 0.01926347, 0.00350082], dtype=float32), 'mean_outer_loss': 0.01883908547461033, 'accuracies_before': array([0.5897436 , 0.71428573, 0.8095238 , 0.65384614], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.0289083 , 1.2904606 , 0.50433147, 1.3215224 ]], dtype=float32), 'outer_losses': array([0.05012345, 0.00041267, 0.01848498, 0.00346939], dtype=float32), 'mean_outer_loss': 0.01812262088060379, 'accuracies_before': array([0.5897436 , 0.71428573, 0.85714287, 0.6923077 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.044487  , 1.305921  , 0.49342528, 1.3371694 ]], dtype=float32), 'outer_losses': array([0.048124  , 0.00037696, 0.01780058, 0.00342569], dtype=float32), 'mean_outer_loss': 0.01743180677294731, 'accuracies_before': array([0.5897436 , 0.71428573, 0.85714287, 0.6923077 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}
# {'num_tasks': 4, 'inner_losses': array([[2.0596557 , 1.3207549 , 0.48488972, 1.3531066 ]], dtype=float32), 'outer_losses': array([0.04612958, 0.00034654, 0.01719437, 0.00336606], dtype=float32), 'mean_outer_loss': 0.01675913855433464, 'accuracies_before': array([0.5897436 , 0.71428573, 0.85714287, 0.6923077 ], dtype=float32), 'accuracies_after': array([1., 1., 1., 1.], dtype=float32)}

# %%
import json
with open('maml_results.json') as json_file:
    data = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-7b07a86eb8cb> in <module>
#       1 import json
#       2 with open('maml_results.json') as json_file:
# ----> 3     data = json.load(json_file)
#
# /usr/local/Cellar/python@3.9/3.9.2_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/local/Cellar/python@3.9/3.9.2_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/local/Cellar/python@3.9/3.9.2_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/local/Cellar/python@3.9/3.9.2_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)
